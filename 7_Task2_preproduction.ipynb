# %% [markdown]
# # Task 2: Predicting customer buying behaviour
# ## 7. Preproduction code

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import cloudpickle

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from category_encoders import TargetEncoder

from sklearn.preprocessing import QuantileTransformer

from sklearn.preprocessing import MinMaxScaler

from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %% [markdown]
# ## Load the data (original dataset)

# %%
df = pd.read_csv("customer_booking.csv",encoding='ISO-8859-1')
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
#        flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0                7        Sat  AKLDEL    New Zealand                    1
# 1                3        Sat  AKLDEL    New Zealand                    0
# 2               17        Wed  AKLDEL          India                    1
# 3                4        Sat  AKLDEL    New Zealand                    0
# 4               15        Wed  AKLDEL          India                    1
# ...            ...        ...     ...            ...                  ...
# 49995            9        Sat  PERPNH      Australia                    1
# 49996            4        Sun  PERPNH      Australia                    0
# 49997           22        Sat  PERPNH      Australia                    0
# 49998           11        Mon  PERPNH      Australia                    1
# 49999           10        Thu  PERPNH      Australia                    0
#
#        wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                         0                      0             5.52
# 1                         0                      0             5.52
# 2                         1                      0             5.52
# 3                         0                      1             5.52
# 4                         0                      1             5.52
# ...                     ...                    ...              ...
# 49995                     0                      1             5.62
# 49996                     0                      0             5.62
# 49997                     0                      1             5.62
# 49998                     0                      1             5.62
# 49999                     1                      0             5.62
#
#        booking_complete
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 49995                 0
# 49996                 0
# 49997                 0
# 49998                 0
# 49999                 0
#
# [50000 rows x 14 columns]

# %% [markdown]
# ## Enumerate final variables from feature selection

# %%
variables = ["booking_origin","length_of_stay","purchase_lead","flight_duration","flight_hour","flight_day","num_passengers","sales_channel","wants_extra_baggage","wants_preferred_seat","wants_in_flight_meals","route"]
variables
# Out:
# ['booking_origin',
#  'length_of_stay',
#  'purchase_lead',
#  'flight_duration',
#  'flight_hour',
#  'flight_day',
#  'num_passengers',
#  'sales_channel',
#  'wants_extra_baggage',
#  'wants_preferred_seat',
#  'wants_in_flight_meals',
#  'route']

# %% [markdown]
# ## Modify datasets before proceeding to building the pipeline

# %% [markdown]
# ### Remove duplicates

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### Select final variables from df

# %%
x = df[variables].reset_index(drop=True).copy()

target = "booking_complete"
y = df[target].reset_index(drop=True).copy()

# %% [markdown]
# ## Build pipeline

# %% [markdown]
# ### Data cleaning summary

# %% [markdown]
# #### Build function

# %%
def data_cleaning(df):
    # Execute all the steps carried out in step 1 (data cleaning script)
    temp = df
    # Removing outliers from purchase_lead and length_of_stay
    var_clip = ["purchase_lead","length_of_stay"]
    p_min = 0
    p_max = 0.99

    for variable in var_clip:
        temp[variable].clip(lower = temp[variable].quantile(p_min), 
                        upper = temp[variable].quantile(p_max), 
                        inplace = True)
        
    return temp

# %% [markdown]
# #### Convert function to transformer
#
# So we can add it to the pipeline

# %%
trans_data_cleaning = FunctionTransformer(data_cleaning(df))

# %% [markdown]
# ### Feature engineering summary

# %%
var_ohe = ["sales_channel","trip_type","route","booking_origin"]
ohe = OneHotEncoder(sparse_output = False, handle_unknown='ignore')

var_oe = ["flight_day"]
order_flight_day = ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
oe = OrdinalEncoder(categories = [order_flight_day],
                    handle_unknown = 'use_encoded_value',
                    unknown_value = 10)

var_qt = ["num_passengers","purchase_lead","length_of_stay","flight_hour","flight_duration"]
qt = QuantileTransformer(output_distribution='normal')

var_mms = ["flight_day","num_passengers","purchase_lead","length_of_stay","flight_hour"]
mms = MinMaxScaler()

# %% [markdown]
# ### Build preprocessing pipe

# %% [markdown]
# #### Create column transformer

# %%
ct = make_column_transformer(
    (ohe, var_ohe),
    (oe, var_oe),
    (qt, var_qt),
    (mms, var_mms),
    remainder='passthrough')

# %% [markdown]
# ### Build preprocessing pipeline

# %%
pipe_prepro = make_pipeline(trans_data_cleaning, ct)

# %% [markdown]
# ### Instantiate the model

# %%
model = RandomForestClassifier(n_jobs=-1,
                                max_depth=10)

# %% [markdown]
# ### Create training pipeline

# %%
pipe_training = make_pipeline(pipe_prepro, model)

# %% [markdown]
# ### Save the training pipeline

# %%
with open("pipe_training.pickle",mode="wb") as file:
    cloudpickle.dump(pipe_training, file)

# %% [markdown]
# ### Train the pipeline and create production pipeline

# %%
pipe_production = pipe_training.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 pipe_production = pipe_training.fit(x,y)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:401, in Pipeline.fit(self, X, y, **fit_params)
#     375 """Fit the model.
#     376
#     377 Fit all the transformers one after the other and transform the
#    (...)
#     398     Pipeline with fitted steps.
#     399 """
#     400 fit_params_steps = self._check_fit_params(**fit_params)
# --> 401 Xt = self._fit(X, y, **fit_params_steps)
#     402 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403     if self._final_estimator != "passthrough":
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:359, in Pipeline._fit(self, X, y, **fit_params_steps)
#     357     cloned_transformer = clone(transformer)
#     358 # Fit or load from cache the current transformer
# --> 359 X, fitted_transformer = fit_transform_one_cached(
#     360     cloned_transformer,
#     361     X,
#     362     y,
#     363     None,
#     364     message_clsname="Pipeline",
#     365     message=self._log_message(step_idx),
#     366     **fit_params_steps[name],
#     367 )
#     368 # Replace the transformer of the step with the fitted
#     369 # transformer. This is necessary when loading the transformer
#     370 # from the cache.
#     371 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:893, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891 with _print_elapsed_time(message_clsname, message):
#     892     if hasattr(transformer, "fit_transform"):
# --> 893         res = transformer.fit_transform(X, y, **fit_params)
#     894     else:
#     895         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:437, in Pipeline.fit_transform(self, X, y, **fit_params)
#     410 """Fit the model and transform with the final estimator.
#     411
#     412 Fits all the transformers one after the other and transform the
#    (...)
#     434     Transformed samples.
#     435 """
#     436 fit_params_steps = self._check_fit_params(**fit_params)
# --> 437 Xt = self._fit(X, y, **fit_params_steps)
#     439 last_step = self._final_estimator
#     440 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:359, in Pipeline._fit(self, X, y, **fit_params_steps)
#     357     cloned_transformer = clone(transformer)
#     358 # Fit or load from cache the current transformer
# --> 359 X, fitted_transformer = fit_transform_one_cached(
#     360     cloned_transformer,
#     361     X,
#     362     y,
#     363     None,
#     364     message_clsname="Pipeline",
#     365     message=self._log_message(step_idx),
#     366     **fit_params_steps[name],
#     367 )
#     368 # Replace the transformer of the step with the fitted
#     369 # transformer. This is necessary when loading the transformer
#     370 # from the cache.
#     371 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\pipeline.py:893, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891 with _print_elapsed_time(message_clsname, message):
#     892     if hasattr(transformer, "fit_transform"):
# --> 893         res = transformer.fit_transform(X, y, **fit_params)
#     894     else:
#     895         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\base.py:881, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     878     return self.fit(X, **fit_params).transform(X)
#     879 else:
#     880     # fit method of arity 2 (supervised transformation)
# --> 881     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\preprocessing\_function_transformer.py:217, in FunctionTransformer.fit(self, X, y)
#     198 def fit(self, X, y=None):
#     199     """Fit transformer by checking X.
#     200
#     201     If ``validate`` is ``True``, ``X`` will be checked.
#    (...)
#     215         FunctionTransformer class instance.
#     216     """
# --> 217     self._validate_params()
#     218     X = self._check_input(X, reset=True)
#     219     if self.check_inverse and not (self.func is None or self.inverse_func is None):
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_params(self)
#     592 def _validate_params(self):
#     593     """Validate types and values of constructor parameters
#     594
#     595     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     598     accepted constraints.
#     599     """
# --> 600     validate_parameter_constraints(
#     601         self._parameter_constraints,
#     602         self.get_params(deep=False),
#     603         caller_name=self.__class__.__name__,
#     604     )
#
# File c:\Users\Luis\miniconda3\envs\project_BA\Lib\site-packages\sklearn\utils\_param_validation.py:97, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      91 else:
#      92     constraints_str = (
#      93         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      94         f" {constraints[-1]}"
#      95     )
# ---> 97 raise InvalidParameterError(
#      98     f"The {param_name!r} parameter of {caller_name} must be"
#      99     f" {constraints_str}. Got {param_val!r} instead."
#     100 )
#
# InvalidParameterError: The 'func' parameter of FunctionTransformer must be a callable or None. Got        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
#        flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0                7        Sat  AKLDEL    New Zealand                    1
# 1                3        Sat  AKLDEL    New Zealand                    0
# 2               17        Wed  AKLDEL          India                    1
# 3                4        Sat  AKLDEL    New Zealand                    0
# 4               15        Wed  AKLDEL          India                    1
# ...            ...        ...     ...            ...                  ...
# 49995            9        Sat  PERPNH      Australia                    1
# 49996            4        Sun  PERPNH      Australia                    0
# 49997           22        Sat  PERPNH      Australia                    0
# 49998           11        Mon  PERPNH      Australia                    1
# 49999           10        Thu  PERPNH      Australia                    0
#
#        wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                         0                      0             5.52
# 1                         0                      0             5.52
# 2                         1                      0             5.52
# 3                         0                      1             5.52
# 4                         0                      1             5.52
# ...                     ...                    ...              ...
# 49995                     0                      1             5.62
# 49996                     0                      0             5.62
# 49997                     0                      1             5.62
# 49998                     0                      1             5.62
# 49999                     1                      0             5.62
#
#        booking_complete
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 49995                 0
# 49996                 0
# 49997                 0
# 49998                 0
# 49999                 0
#
# [49281 rows x 14 columns] instead.

# %%
x
# Out:
#       booking_origin  length_of_stay  purchase_lead  flight_duration  \
# 0        New Zealand              19            262             5.52
# 1        New Zealand              20            112             5.52
# 2              India              22            243             5.52
# 3        New Zealand              31             96             5.52
# 4              India              22             68             5.52
# ...              ...             ...            ...              ...
# 49276      Australia               6             27             5.62
# 49277      Australia               6            111             5.62
# 49278      Australia               6             24             5.62
# 49279      Australia               6             15             5.62
# 49280      Australia               6             19             5.62
#
#        flight_hour flight_day  num_passengers sales_channel  \
# 0                7        Sat               2      Internet
# 1                3        Sat               1      Internet
# 2               17        Wed               2      Internet
# 3                4        Sat               1      Internet
# 4               15        Wed               2      Internet
# ...            ...        ...             ...           ...
# 49276            9        Sat               2      Internet
# 49277            4        Sun               1      Internet
# 49278           22        Sat               1      Internet
# 49279           11        Mon               1      Internet
# 49280           10        Thu               1      Internet
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# 0                        1                     0                      0
# 1                        0                     0                      0
# 2                        1                     1                      0
# 3                        0                     0                      1
# 4                        1                     0                      1
# ...                    ...                   ...                    ...
# 49276                    1                     0                      1
# 49277                    0                     0                      0
# 49278                    0                     0                      1
# 49279                    1                     0                      1
# 49280                    0                     1                      0
#
#         route
# 0      AKLDEL
# 1      AKLDEL
# 2      AKLDEL
# 3      AKLDEL
# 4      AKLDEL
# ...       ...
# 49276  PERPNH
# 49277  PERPNH
# 49278  PERPNH
# 49279  PERPNH
# 49280  PERPNH
#
# [49281 rows x 12 columns]
